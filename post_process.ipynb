# %%
import pandas as pd

# %%
df = pd.read_csv('job_details.csv', encoding='utf-8')
df.head()
# Out:
#                                                title companyName  \
# 0  Manager, Software Engineer - (ReactJS and NodeJS)     Repucom
# 1                          Manager Software Engineer     Repucom
# 2                          Storage Software Engineer         IBM
# 3                   Distinguished, Software Engineer     Walmart
# 4                Software Engineer\nBengaluru, India     Cargill
#
#           location experience         salary currency  \
# 0        Bengaluru   6-11 Yrs  Not disclosed      INR
# 1        Bengaluru   7-12 Yrs  Not disclosed      INR
# 2  Pune, Bengaluru   5-10 Yrs  Not disclosed      INR
# 3        Bengaluru   8-12 Yrs  Not disclosed      INR
# 4        Bengaluru    3-5 Yrs  Not disclosed      INR
#
#                                        tagsAndSkills  \
# 0  Unix,Linux,Coding,MIS,MySQL,Shell scripting,Ag...
# 1  Unix,C++,Linux,Coding,Shell scripting,Applicat...
# 2  java,dump analysis,debugging,agile,system soft...
# ...

# %%
len(df)
# Out:
# 4000
